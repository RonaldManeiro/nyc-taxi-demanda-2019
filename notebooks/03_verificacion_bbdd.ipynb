# %% [markdown]
# # Importamos librerias y conectamos con la base de datos

# %%
import pandas as pd
import os 

file_path = os.path.join("..", "data", "processed", "tripdata_clean.csv")

# cargamos datos 
df= pd.read_csv(file_path)
df.head()
# Out:
#   tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  trip_distance  \
# 0  2019-12-01 00:26:58   2019-12-01 00:41:45                1            4.2
# 1  2019-12-01 00:12:03   2019-12-01 00:33:19                2            9.4
# 2  2019-12-01 00:05:27   2019-12-01 00:16:32                2            1.6
# 3  2019-12-01 00:58:51   2019-12-01 01:08:37                2            1.0
# 4  2019-12-01 00:19:48   2019-12-01 00:24:18                1            0.9
#
#    pulocationid  dolocationid  payment_type  fare_amount  tip_amount  \
# 0           142           116           2.0         14.5        0.00
# 1           138            25           1.0         28.5       10.00
# 2           161           237           2.0          9.0        0.00
# 3           161           230           2.0          6.5        0.00
# 4           148             4           1.0          5.5        1.85
#
#    total_amount  congestion_surcharge  trip_duration_min
# ...

# %% [markdown]
# # Informacion del DataFrame
# __Ver cantidad de filas y columnas.__
# __Ver nombres de columnas.__
# __Que tipos de datos.__
# __Analizar posibles columnas mal interpretadas.__

# %%
print ("Shape (filas, columnas): ", df.shape)
print ("\nColumnas del dataset:")
print (df.columns)

print ("\nTipos de datos:")
print (df.dtypes)
# Out:
# Shape (filas, columnas):  (6615438, 12)
#
# Columnas del dataset:
# Index(['tpep_pickup_datetime', 'tpep_dropoff_datetime', 'passenger_count',
#        'trip_distance', 'pulocationid', 'dolocationid', 'payment_type',
#        'fare_amount', 'tip_amount', 'total_amount', 'congestion_surcharge',
#        'trip_duration_min'],
#       dtype='object')
#
# Tipos de datos:
# tpep_pickup_datetime      object
# tpep_dropoff_datetime     object
# passenger_count            int64
# trip_distance            float64
# pulocationid               int64
# dolocationid               int64
# payment_type             float64
# fare_amount              float64
# tip_amount               float64
# total_amount             float64
# congestion_surcharge     float64
# trip_duration_min        float64
# dtype: object

# %%
# Valores nulos 
print ("Valores nulos por columna:")
print (df.isnull().sum())
# Out:
# Valores nulos por columna:
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# pulocationid             0
# dolocationid             0
# payment_type             0
# fare_amount              0
# tip_amount               0
# total_amount             0
# congestion_surcharge     0
# trip_duration_min        0
# dtype: int64

# %%
df.describe()
# Out:
#        passenger_count  trip_distance  pulocationid  dolocationid  \
# count     6.615438e+06   6.615438e+06  6.615438e+06  6.615438e+06
# mean      1.581482e+00   2.976829e+00  1.639114e+02  1.616266e+02
# std       1.167270e+00   3.885100e+00  6.588021e+01  7.016653e+01
# min       1.000000e+00   1.000000e-02  1.000000e+00  1.000000e+00
# 25%       1.000000e+00   9.800000e-01  1.250000e+02  1.120000e+02
# 50%       1.000000e+00   1.610000e+00  1.620000e+02  1.620000e+02
# 75%       2.000000e+00   3.010000e+00  2.340000e+02  2.340000e+02
# max       9.000000e+00   1.735000e+02  2.650000e+02  2.650000e+02
#
#        payment_type   fare_amount    tip_amount  total_amount  \
# count  6.615438e+06  6.615438e+06  6.615438e+06  6.615438e+06
# mean   1.290172e+00  1.330692e+01  2.262078e+00  1.940099e+01
# std    4.699574e-01  1.197863e+01  2.797790e+00  1.477755e+01
# min    1.000000e+00  1.000000e-02  0.000000e+00  3.100000e-01
# ...
